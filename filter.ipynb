# %%
import pandas as pd

df = pd.read_csv('itineraries.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-3-bf6be90c1dda> in <cell line: 3>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv('itineraries.csv')
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
dfl = filter(lambda x : x.startingAirport == 'LAX', df)
dflax = filter(lambda x : x.destinationAirport == 'LAX', dfl)

dflax.size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-ea15f95806ea> in <cell line: 1>()
# ----> 1 dfl = filter(lambda x : x.startingAirport == 'LAX', df)
#       2 dflax = filter(lambda x : x.destinationAirport == 'LAX', dfl)
#       3
#       4 dflax.size
#
# NameError: name 'df' is not defined
